# %% [markdown]
# # Embedding and Reranker Fine-tuning Analysis
#
# This notebook provides analysis and visualization of the fine-tuning results.

# %%
import sys
import os
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path

# Import our modules
from src.data.dataset_loader import DatasetLoader
from src.inference.pipeline import SearchPipeline, create_demo_corpus
from src.evaluation.metrics import RankingMetrics

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
